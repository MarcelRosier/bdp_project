# %% [markdown]
# # Gini dataset
# from : https://data.worldbank.org/indicator/SI.POV.GINI?end=2021&most_recent_value_desc=true&start=2021&view=map

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import utils
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.10f' % x)

# %%
melted_df = utils.load_gini()

# %%
# melted_df = df.melt(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'],var_name="year", value_name='gini')
# melted_df

# %%
# drop na gini fields
# print(f"pre {melted_df.shape}")
# melted_df = melted_df[melted_df['gini'].notna()]
# print(f"after {melted_df.shape}")

# %%
# check years with a lot of data
melted_df.groupby('year').count()['country'].sort_index(ascending=False)
# looks good for the past 10 years
# Out:
# year
# 2021     1
# 2020    20
# 2019    60
# 2018    85
# 2017    77
# 2016    83
# 2015    85
# 2014    83
# 2013    77
# 2012    85
# 2011    78
# 2010    84
# 2009    78
# 2008    74
# 2007    70
# 2006    76
# 2005    75
# 2004    70
# 2003    59
# 2002    53
# 2001    35
# 2000    49
# 1999    32
# 1998    37
# 1997    28
# 1996    31
# 1995    36
# 1994    26
# 1993    22
# 1992    31
# 1991    19
# 1990    17
# 1989    13
# 1988     9
# 1987    20
# 1986    14
# 1985    11
# 1984     5
# 1983     4
# 1982     2
# 1981     7
# 1980     3
# 1979     5
# 1978     1
# 1977     1
# 1975     2
# 1974     2
# 1971     1
# 1969     1
# 1967     1
# Name: country, dtype: int64

# %% [markdown]
# ## Example gini development for sweden

# %%
melted_df[melted_df['country'] == "Sweden"].sort_values(by="year")
# melted_df
# Out:
#       country country_code  year          gini
# 2085   Sweden          SWE  1967 34.0000000000
# 4213   Sweden          SWE  1975 24.3000000000
# 5809   Sweden          SWE  1981 22.9000000000
# 7405   Sweden          SWE  1987 23.1000000000
# 8735   Sweden          SWE  1992 24.9000000000
# 9533   Sweden          SWE  1995 25.2000000000
# 10863  Sweden          SWE  2000 27.2000000000
# 11661  Sweden          SWE  2003 25.3000000000
# 11927  Sweden          SWE  2004 26.1000000000
# 12193  Sweden          SWE  2005 26.8000000000
# 12459  Sweden          SWE  2006 26.4000000000
# 12725  Sweden          SWE  2007 27.1000000000
# 12991  Sweden          SWE  2008 28.1000000000
# 13257  Sweden          SWE  2009 27.3000000000
# 13523  Sweden          SWE  2010 27.7000000000
# 13789  Sweden          SWE  2011 27.6000000000
# 14055  Sweden          SWE  2012 27.6000000000
# 14321  Sweden          SWE  2013 28.8000000000
# 14587  Sweden          SWE  2014 28.4000000000
# 14853  Sweden          SWE  2015 29.2000000000
# 15119  Sweden          SWE  2016 29.6000000000
# 15385  Sweden          SWE  2017 28.8000000000
# 15651  Sweden          SWE  2018 30.0000000000
# 15917  Sweden          SWE  2019 29.3000000000

# %%
# melted_df.year = melted_df.year.astype(int)
# melted_df = melted_df[melted_df.year.between(2010,2015)]
# melted_df
# Out:
#              country country_code  year          gini
# 13309      Argentina          ARG  2010 43.6000000000
# 13310        Armenia          ARM  2010 30.0000000000
# 13313      Australia          AUS  2010 34.7000000000
# 13314        Austria          AUT  2010 30.3000000000
# 13317        Belgium          BEL  2010 28.4000000000
# ...              ...          ...   ...           ...
# 14878        Ukraine          UKR  2015 25.5000000000
# 14880        Uruguay          URY  2015 40.1000000000
# 14881  United States          USA  2015 41.2000000000
# 14891         Kosovo          XKX  2015 26.5000000000
# 14894         Zambia          ZMB  2015 57.1000000000
#
# [492 rows x 4 columns]

# %%
sns.lineplot(data=melted_df, x='year',y='gini', hue='country', legend=False)
# Out:
# <AxesSubplot: xlabel='year', ylabel='gini'>

# %%
# gini trends
def trendline(x, y, order=1):
    slope = np.polyfit(x, y, order)[-2]
    print(np.polyfit(x, y, order))
    return float(slope)

def apply_trendline(df):
    return trendline(df.year.values, df.gini.values)

trends = melted_df.groupby('country').apply(apply_trendline).sort_values()[::-1]
# sns.scatterplot(trends_per_country, y='country')
fig, ax = plt.subplots(figsize=(3,12))
sns.scatterplot(x=trends.values, y=trends.keys(), ax=ax)
# Out:
# [ 1.48571429e+00 -2.95960000e+03]
# [6.86225758e-03 1.38000000e+01]
# [-5.70000e-01  1.18884e+03]
# [ 5.51428571e-01 -1.07916667e+03]
# [-7.5000e-02  1.8545e+02]
# [0.01142857 7.56666667]
# [7.98507463e-03 1.60500000e+01]
# [-4.25714286e-01  8.83700000e+02]
# [-9.42857143e-02  2.17666667e+02]
# [ 1.1000e+00 -2.1687e+03]
# [9.64214712e-03 1.94000000e+01]
# [ 2.4000e-01 -4.3616e+02]
# [8.2048732e-03 1.6500000e+01]
# [1.32258065e-02 2.66500000e+01]
# [-3.40e-01  7.37e+02]
# [ 6.97142857e-01 -1.36656667e+03]
# [8.76365442e-03 1.76500000e+01]
# [9.58768008e-03 1.93000000e+01]
# [1.05210918e-02 2.12000000e+01]
# [1.15690169e-02 2.33000000e+01]
# [-9.45945946e-03  5.26000000e+01]
# [1.07657882e-02 2.16500000e+01]
# [-4.000e-01  8.506e+02]
# [-1.07428571e+00  2.20296667e+03]
# [-5.91428571e-01  1.24306667e+03]
# [1.12462761e-02 2.26500000e+01]
# [1.04622266e-02 2.10500000e+01]
# [1.21581303e-02 2.44500000e+01]
# [ 6.28571429e-02 -7.79333333e+01]
# [1.02977667e-02 2.07500000e+01]
# [-2.17142857e-01  4.69066667e+02]
# [ 6.91428571e-01 -1.35733333e+03]
# [-1.31428571e-01  2.90733333e+02]
# [ 2.57142857e-01 -4.89600000e+02]
# [-1.0000e+00  2.0571e+03]
# [-5.45714286e-01  1.14463333e+03]
# [-4.54285714e-01  9.60700000e+02]
# [ 3.86842105e-01 -7.48355263e+02]
# [-4.28571429e-01  9.04700000e+02]
# [ 3.42857143e-01 -6.56700000e+02]
# [ 3.600e-01 -6.904e+02]
# [9.11574764e-03 1.83500000e+01]
# [-1.51428571e-01  3.32000000e+02]
# [-2.45714286e-01  5.27433333e+02]
# [-1.540e+00  3.139e+03]
# [-6.11428571e-01  1.26896667e+03]
# [ 2.05714286e-01 -3.82966667e+02]
# [1.05367793e-02 2.12000000e+01]
# [ 3.51428571e-01 -6.71733333e+02]
# [1.19910626e-02 2.41500000e+01]
# [8.37475149e-03 1.68500000e+01]
# [1.26119403e-02 2.53500000e+01]
# [1.02137177e-02 2.05500000e+01]
# [-8.85714286e-01  1.83386667e+03]
# [ 3.08571429e-01 -5.90633333e+02]
# [ 1.31428571e-01 -2.37866667e+02]
# [-2.5000e-01  5.3845e+02]
# [ 4.40000000e-01 -8.45566667e+02]
# [ 1.05000000e+00 -2.07613333e+03]
# [7.33101392e-03 1.47500000e+01]
# [-1.48571429e-01  3.31600000e+02]
# [-5.77142857e-01  1.20236667e+03]
# [ 5.71428571e-02 -8.00000000e+01]
# [ 2.66666667e-01 -5.03900000e+02]
# [8.38308458e-03 1.68500000e+01]
# [-2.88571429e-01  6.08266667e+02]
# [1.01240695e-02 2.04000000e+01]
# [-2.00e-01  4.34e+02]
# [-1.09142857e+00  2.22486667e+03]
# [-2.02857143e-01  4.36566667e+02]
# [8.94632207e-03 1.80000000e+01]
# [-1.65714286e-01  3.68633333e+02]
# [7.90651417e-03 1.59000000e+01]
# [8.24230387e-03 1.66000000e+01]
# [ 9.94285714e-01 -1.96573333e+03]
# [ 2.00000000e-01 -3.70333333e+02]
# [ 1.000e-01 -1.586e+02]
# [1.1318408e-02 2.2750000e+01]
# [-7.0000e-01  1.4512e+03]
# [ 3.14285714e-02 -3.41333333e+01]
# [8.09334657e-03 1.63000000e+01]
# [9.56759443e-03 1.92500000e+01]
# [ 3.750e-01 -7.063e+02]
# [9.96025832e-03 2.00500000e+01]
# [-1.07428571e+00  2.19103333e+03]
# [-3.31428571e-01  6.99951429e+02]
# [-6.80000e-01  1.40868e+03]
# [9.81122702e-03 1.97500000e+01]
# [1.34061569e-02 2.70000000e+01]
# [9.45409429e-03 1.90500000e+01]
# [1.46650124e-02 2.95500000e+01]
# [8.64811133e-03 1.74000000e+01]
# [8.15920398e-03 1.64000000e+01]
# [ 1.40000000e-01 -2.53733333e+02]
# [1.1469712e-02 2.3100000e+01]
# [ 9.33333333e-01 -1.84543333e+03]
# [ 4.73684211e-02 -5.96210526e+01]
# [-1.07142857e+00  2.19370000e+03]
# [ 4.05714286e-01 -7.90266667e+02]
# [ 4.25423729e-01 -8.26233898e+02]
# [-1.88571429e-01  4.30733333e+02]
# [-6.14285714e-01  1.28576667e+03]
# [-4.51428571e-01  9.52666667e+02]
# [-6.33333333e-01  1.32076667e+03]
# [-2.31428571e-01  4.98600000e+02]
# [-9.71428571e-02  2.31400000e+02]
# [ 7.71428571e-02 -1.19133333e+02]
# [-2.34285714e-01  5.11233333e+02]
# [-7.0000e-01  1.4542e+03]
# [9.61251863e-03 1.93500000e+01]
# [7.66169154e-03 1.54000000e+01]
# [1.00198906e-02 2.01500000e+01]
# [ 2.8000e-01 -5.2368e+02]
# [1.16244411e-02 2.34000000e+01]
# [8.45350572e-03 1.70000000e+01]
# [-9.14285714e-02  2.10766667e+02]
# [ 1.57142857e-01 -2.90800000e+02]
# [9.21968191e-03 1.85500000e+01]
# [-1.000e-01  2.644e+02]
# [ 2.000e-01 -3.667e+02]
# [9.61729622e-03 1.93500000e+01]
# [8.49056604e-03 1.71000000e+01]
# [ 3.17142857e-01 -6.10033333e+02]
# [ 5.14285714e-02 -7.13000000e+01]
# [8.43672457e-03 1.70000000e+01]
# [9.3983093e-03 1.8900000e+01]
# [-5.71428571e-01  1.18783333e+03]
# [7.12512413e-03 1.43500000e+01]
# [-7.250000e-01  1.503975e+03]
# [9.33002481e-03 1.88000000e+01]
# [-6.0000e-01  1.2418e+03]
# [ 6.88571429e-01 -1.34520000e+03]
# [9.72636816e-03 1.95500000e+01]
# [1.01888668e-02 2.05000000e+01]
# [ 4.57142857e-02 -6.73000000e+01]
# [8.07252856e-03 1.62500000e+01]
# [-7.71428571e-02  1.88633333e+02]
# [ 2.17142857e-01 -3.96133333e+02]
# [-7.91428571e-01  1.63396667e+03]
# [9.30348259e-03 1.87000000e+01]
# [-1.12500000e+00  2.30006667e+03]
# [-9.0000e-01  1.8443e+03]
# [9.11122145e-03 1.83500000e+01]
# [ 3.000e-01 -5.474e+02]
# [1.07409249e-02 2.16000000e+01]
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_44896/925907676.py:8: RankWarning: Polyfit may be poorly conditioned
#   return trendline(df.year.values, df.gini.values)
# <AxesSubplot: ylabel='country'>

# %%
country_count = melted_df.groupby('country').year.count()
countries = [country for country, count in zip(country_count.keys(),country_count.values) if count == 6]
len(countries)
# test = melted_df.groupby('country').year.count().sort_values()
# Out:
# 57
