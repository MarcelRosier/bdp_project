# %%
from analysis import ModelAnalysis
from sklearn.linear_model import LinearRegression
import numpy as np
np.random.seed(42)

# %%
# define models
linear_default = LinearRegression()
linear_positive = LinearRegression(positive=True)

ma = ModelAnalysis(models={
    'linear_default': linear_default,
    'linear_positive': linear_positive
})

# %%
ma.train()
_ = ma.predict(split='train')
_ = ma.predict(split='val')
# Out:
# Fitting linear_default
# Fitting linear_positive

# %%
ma.visualize_predictions(split='train')
ma.visualize_predictions(split='val')
# Out:
# /Users/marcelrosier/Projects/uni/master/bdp/bdp_project/mental_health/analysis.py:115: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(pred_df, markers=True, alpha=.6,
# /Users/marcelrosier/Projects/uni/master/bdp/bdp_project/mental_health/analysis.py:119: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.lineplot(pred_df[[k for k in self.models.keys() if k != 'Y']],
# /Users/marcelrosier/Projects/uni/master/bdp/bdp_project/mental_health/analysis.py:115: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(pred_df, markers=True, alpha=.6,
# /Users/marcelrosier/Projects/uni/master/bdp/bdp_project/mental_health/analysis.py:119: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.lineplot(pred_df[[k for k in self.models.keys() if k != 'Y']],

# %%
df = ma.visualize_metrics(split='train',verbose=True)
df = ma.visualize_metrics(split='val',verbose=True)
# Out:
# mean_squared_error
#              model          score
# 0   linear_default  329995.455040
# 1  linear_positive  344225.471151
# r2_score
#              model     score
# 0   linear_default  0.606897
# 1  linear_positive  0.589946
# max_error
#              model        score
# 0   linear_default  5584.365123
# 1  linear_positive  5725.424540
# root_mean_squared_error
#              model       score
# 0   linear_default  574.452309
# 1  linear_positive  586.707313
# mean_absolute_error
#              model       score
# 0   linear_default  294.633496
# 1  linear_positive  302.032205
# mean_squared_error
#              model          score
# 0   linear_default  683394.196551
# 1  linear_positive  708749.449850
# r2_score
#              model     score
# 0   linear_default  0.685771
# 1  linear_positive  0.674113
# max_error
#              model        score
# 0   linear_default  5557.210268
# 1  linear_positive  5769.891595
# root_mean_squared_error
#              model       score
# 0   linear_default  826.676597
# 1  linear_positive  841.872585
# mean_absolute_error
#              model       score
# 0   linear_default  368.851324
# 1  linear_positive  370.927508

# %%
# save models
ma.save_models(base_path="models/linear")
