# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import utils
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.10f' % x)

# %%
df = pd.read_csv('datasets/suicide_ds_2016.csv')

# %%
df.info()
dir(utils)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'country_name_map',
#  'get_train_test_split_legacy',
#  'get_train_val_test_split',
#  'load_gini',
#  'load_healthcare',
#  'load_suicide_data',
#  'load_suicide_healthcare_gini_df',
#  'math',
#  'mean_squared_error',
#  'np',
#  'pc',
#  'pd',
#  'plt',
#  'pycountry',
#  'root_mean_squared_error',
#  'sns',
#  'train_test_split']

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0       6.7100000000  Albania1987           NaN      2,156,624,900
# 1       5.1900000000  Albania1987           NaN      2,156,624,900
# 2       4.8300000000  Albania1987           NaN      2,156,624,900
# 3       4.5900000000  Albania1987           NaN      2,156,624,900
# 4       3.2800000000  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
df.tail()
# Out:
#           country  year     sex          age  suicides_no  population  \
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 27815       2.9600000000  Uzbekistan2014  0.6750000000     63,067,077,179
# 27816       2.5800000000  Uzbekistan2014  0.6750000000     63,067,077,179
# 27817       2.1700000000  Uzbekistan2014  0.6750000000     63,067,077,179
# 27818       1.6700000000  Uzbekistan2014  0.6750000000     63,067,077,179
# 27819       1.4600000000  Uzbekistan2014  0.6750000000     63,067,077,179
#
#        gdp_per_capita ($)    generation
# 27815                2309  Generation X
# 27816                2309        Silent
# 27817                2309  Generation Z
# 27818                2309  Generation Z
# 27819                2309       Boomers

# %%
df.nunique()
# Out:
# country                 101
# year                     32
# sex                       2
# age                       6
# suicides_no            2084
# population            25564
# suicides/100k pop      5298
# country-year           2321
# HDI for year            305
#  gdp_for_year ($)      2321
# gdp_per_capita ($)     2233
# generation                6
# dtype: int64

# %%
df.shape
# Out:
# (27820, 12)

# %%
df.isna().sum()
df[df.year.between(2010,2015)].isna().sum()
# Out:
# country                 0
# year                    0
# sex                     0
# age                     0
# suicides_no             0
# population              0
# suicides/100k pop       0
# country-year            0
# HDI for year          960
#  gdp_for_year ($)       0
# gdp_per_capita ($)      0
# generation              0
# dtype: int64

# %% [markdown]
# # Tidy data
# - Drop columns:
#     - remove HDI for year
#     - remove country-year
# - Rename columns:
#     - 'suicides/100k pop'  => suicides_per_100k_pop
#     - ' gdp_for_year ($) ' => gdp_for_year
#     - 'gdp_per_capita ($)' => gdp_per_capita
# - Remove data points:
#     - remove data from 2016 due to incompleteness

# %%
# HDI has a lot of missing data -> drop the column
# country-year is not needed -> drop
# generation also controversial according to kaggle examples
tidy_df = df.drop(['HDI for year', 'country-year'], axis='columns')

# rename collumns to be snake case confirm and remove currency
tidy_df = tidy_df.rename(columns=
    {
        'suicides/100k pop': 'suicides_per_100k_pop',
        # the extra spaces in the name below are intended!
        ' gdp_for_year ($) ': 'gdp_for_year',
        'gdp_per_capita ($)':'gdp_per_capita'
    })
tidy_df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides_per_100k_pop', 'gdp_for_year', 'gdp_per_capita',
#        'generation'],
#       dtype='object')

# %%
# find missing rows
counts = tidy_df.groupby(['country', 'year']).count()
counts.where(counts < 12).dropna()
# for 16 countries there is data missing in 2016 
# => remove that year to prevent misinterpretation
tidy_df = tidy_df[tidy_df['year'] != 2016]

# %%
temp = tidy_df.groupby(['country', 'year']).count().reset_index()
temp = temp[['country','year']]
country_years = temp.groupby('country').count()
ax = country_years.value_counts(sort=False).plot.bar()
ax.set_xlabel('#years with data')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# plot above shows available data.
# 31 is max (1985 to 2015)
# Whats a reasonable cutoff?
# 10 years?

# %%
# get country names with less than k years of data available
temp = country_years.reset_index()
MIN_DATA_YEARS = 3
names = temp[temp.year <= MIN_DATA_YEARS].country.values
names
# Out:
# array(['Bosnia and Herzegovina', 'Cabo Verde', 'Dominica', 'Macau',
#        'Oman', 'Saint Kitts and Nevis', 'San Marino'], dtype=object)

# %%
# remove countries determined above by using .isin with the prepended negation (~))
tidy_df = tidy_df[~tidy_df['country'].isin(names)]
tidy_df.shape
# Out:
# (27492, 10)

# %% [markdown]
# ## Plot to show that thera are no jumps in the populations

# %%
temp = tidy_df.groupby(['country', 'year', 'sex', 'age']).sum()['population'].reset_index()
temp = temp.groupby(['country','year']).sum().reset_index()

# sns.relplot(data=temp,x='year',y='population',col='country', col_wrap=5,kind='line')
# Out:
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_25235/2694070458.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   temp = tidy_df.groupby(['country', 'year', 'sex', 'age']).sum()['population'].reset_index()
# /var/folders/v4/5kdk6t_57x3gwhsz8x8jl_900000gn/T/ipykernel_25235/2694070458.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   temp = temp.groupby(['country','year']).sum().reset_index()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 temp = tidy_df.groupby(['country', 'year', 'sex', 'age']).sum()['population'].reset_index()
#       2 temp = temp.groupby(['country','year']).sum().reset_index()
# ----> 4 sns.relplot(data=temp,x='year',y='population',col='country', col_wrap=5,kind='line')
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/seaborn/relational.py:955, in relplot(data, x, y, hue, size, style, units, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     946 g = FacetGrid(
#     947     data=full_data.dropna(axis=1, how="all"),
#     948     **grid_kws,
#    (...)
#     951     **facet_kws
#     952 )
#     954 # Draw the plot
# --> 955 g.map_dataframe(func, **plot_kws)
#     957 # Label the axes, using the original variables
#     958 # Pass "" when the variable name is None to overwrite internal variables
#     959 g.set_axis_labels(variables.get("x") or "", variables.get("y") or "")
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/seaborn/axisgrid.py:819, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     816     kwargs["data"] = data_ijk
#     818     # Draw the plot
# --> 819     self._facet_plot(func, ax, args, kwargs)
#     821 # For axis labels, prefer to use positional args for backcompat
#     822 # but also extract the x/y kwargs and use if no corresponding arg
#     823 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/seaborn/axisgrid.py:848, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     846     plot_args = []
#     847     plot_kwargs["ax"] = ax
# --> 848 func(*plot_args, **plot_kwargs)
#     850 # Sort out the supporting information
#     851 self._update_legend_data(ax)
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/seaborn/relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/seaborn/relational.py:515, in _LinePlotter.plot(self, ax, kws)
#     512                     obj.set_capstyle(line_capstyle)
#     514 # Finalize the axes details
# --> 515 self._add_axis_labels(ax)
#     516 if self.legend:
#     517     self.add_legend_data(ax)
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/seaborn/_oldcore.py:1328, in VectorPlotter._add_axis_labels(self, ax, default_x, default_y)
#    1323 # TODO ax could default to None and use attached axes if present
#    1324 # but what to do about the case of facets? Currently using FacetGrid's
#    1325 # set_axis_labels method, which doesn't add labels to the interior even
#    1326 # when the axes are not shared. Maybe that makes sense?
#    1327 if not ax.get_xlabel():
# -> 1328     x_visible = any(t.get_visible() for t in ax.get_xticklabels())
#    1329     ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1330 if not ax.get_ylabel():
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axes/_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axis.py:1388, in Axis.get_ticklabels(self, minor, which)
#    1386 if minor:
#    1387     return self.get_minorticklabels()
# -> 1388 return self.get_majorticklabels()
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axis.py:1345, in Axis.get_majorticklabels(self)
#    1343 def get_majorticklabels(self):
#    1344     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1345     self._update_ticks()
#    1346     ticks = self.get_major_ticks()
#    1347     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axis.py:1190, in Axis._update_ticks(self)
#    1185 def _update_ticks(self):
#    1186     """
#    1187     Update ticks (position and labels) using the current data interval of
#    1188     the axes.  Return the list of ticks that will be drawn.
#    1189     """
# -> 1190     major_locs = self.get_majorticklocs()
#    1191     major_labels = self.major.formatter.format_ticks(major_locs)
#    1192     major_ticks = self.get_major_ticks(len(major_locs))
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axis.py:1416, in Axis.get_majorticklocs(self)
#    1414 def get_majorticklocs(self):
#    1415     """Return this Axis' major tick locations in data coordinates."""
# -> 1416     return self.major.locator()
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/ticker.py:2142, in MaxNLocator.__call__(self)
#    2141 def __call__(self):
# -> 2142     vmin, vmax = self.axis.get_view_interval()
#    2143     return self.tick_values(vmin, vmax)
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axis.py:2162, in _make_getset_interval.<locals>.getter(self)
#    2160 def getter(self):
#    2161     # docstring inherited.
# -> 2162     return getattr(getattr(self.axes, lim_name), attr_name)
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axes/_base.py:815, in _AxesBase.viewLim(self)
#     813 @property
#     814 def viewLim(self):
# --> 815     self._unstale_viewLim()
#     816     return self._viewLim
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axes/_base.py:810, in _AxesBase._unstale_viewLim(self)
#     808     for ax in self._shared_axes[name].get_siblings(self):
#     809         ax._stale_viewlims[name] = False
# --> 810 self.autoscale_view(**{f"scale{name}": scale
#     811                        for name, scale in need_scale.items()})
#
# File ~/opt/anaconda3/envs/bdp/lib/python3.10/site-packages/matplotlib/axes/_base.py:2888, in _AxesBase.autoscale_view(self, tight, scalex, scaley)
#    2881 if self.use_sticky_edges:
#    2882     # Only iterate over Axes and artists if needed.  The check for
#    2883     # ``hasattr(ax, "_children")`` is necessary because this can be
#    2884     # called very early in the Axes init process (e.g., for twin Axes)
#    2885     # when these attributes don't even exist yet, in which case
#    2886     # `get_children` would raise an AttributeError.
#    2887     if self._xmargin and scalex and self.get_autoscalex_on():
# -> 2888         x_stickies = np.sort(np.concatenate([
#    2889             artist.sticky_edges.x
#    2890             for ax in self._shared_axes["x"].get_siblings(self)
#    2891             if hasattr(ax, "_children")
#    2892             for artist in ax.get_children()]))
#    2893     if self._ymargin and scaley and self.get_autoscaley_on():
#    2894         y_stickies = np.sort(np.concatenate([
#    2895             artist.sticky_edges.y
#    2896             for ax in self._shared_axes["y"].get_siblings(self)
#    2897             if hasattr(ax, "_children")
#    2898             for artist in ax.get_children()]))
#
# File <__array_function__ internals>:200, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# #

# %% [markdown]
# ## Add contintent info to data
# use python countrycode package

# %%
import pycountry_convert as pc
from pycountry import pycountry
# # [c.name for c in pycountry.countries]
name_map = {
    'Saint Vincent and Grenadines':'Saint Vincent and the Grenadines',
    'Republic of Korea': 'Korea, Republic of',
}


# def country_name_to_continent_code(country):
#     if country in name_map:
#         country = name_map[country]
#     country_code = pc.country_name_to_country_alpha2(country, cn_name_format="default")
#     # print(country_code)
#     continent_code = pc.country_alpha2_to_continent_code(country_code)
#     # print(continent_name)
#     return pc.convert_continent_code_to_continent_name(continent_code)

# tidy_df['continent'] = [country_name_to_continent_code(country) for country in tidy_df.country]
# tidy_df

# %%
# get num of recorded years per country from tidy_df
recorded_years_per_country = tidy_df.groupby(['country','year']).count().reset_index()[['country','year']]
recorded_years_per_country = recorded_years_per_country.groupby('country').count().reset_index().sort_values(by='year')
recorded_years_per_country = recorded_years_per_country.rename(columns={
    'year' : 'recorded_years'
})
recorded_years_per_country['country_code'] = [
  pc.country_name_to_country_alpha3(name_map.get(c,c))  for c in recorded_years_per_country.country
]
recorded_years_per_country

import geopandas
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world.columns
# world = world.drop(columns=['pop_est', 'iso_a3', 'gdp_md_est'], axis='columns')
# world = world.rename(columns=
#     {
#         'name':'country'
#     })
merged_df = pd.merge(world,recorded_years_per_country,left_on='iso_a3',right_on='country_code', how='left')

# replace NaN with 0
merged_df['recorded_years'] = merged_df['recorded_years'].fillna(0)
merged_df
# Out:
#                  pop_est      continent                      name iso_a3  \
# 0      889953.0000000000        Oceania                      Fiji    FJI
# 1    58005463.0000000000         Africa                  Tanzania    TZA
# 2      603253.0000000000         Africa                 W. Sahara    ESH
# 3    37589262.0000000000  North America                    Canada    CAN
# 4   328239523.0000000000  North America  United States of America    USA
# ..                   ...            ...                       ...    ...
# 172   6944975.0000000000         Europe                    Serbia    SRB
# 173    622137.0000000000         Europe                Montenegro    MNE
# 174   1794248.0000000000         Europe                    Kosovo    -99
# 175   1394973.0000000000  North America       Trinidad and Tobago    TTO
# 176  11062113.0000000000         Africa                  S. Sudan    SSD
#
#      gdp_md_est                                           geometry  \
# 0          5496  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1         63177  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2           907  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3       1736425  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4      21433226  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..          ...                                                ...
# 172       51475  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173        5542  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174        7926  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175       24269  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176       11998  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#                  country  recorded_years country_code
# 0                   Fiji   11.0000000000          FJI
# 1                    NaN    0.0000000000          NaN
# 2                    NaN    0.0000000000          NaN
# 3                 Canada   29.0000000000          CAN
# 4          United States   31.0000000000          USA
# ..                   ...             ...          ...
# 172               Serbia   18.0000000000          SRB
# 173           Montenegro   10.0000000000          MNE
# 174                  NaN    0.0000000000          NaN
# 175  Trinidad and Tobago   27.0000000000          TTO
# 176                  NaN    0.0000000000          NaN
#
# [177 rows x 9 columns]

# %% [markdown]
# ## Plot showing the number of recorded years per country on a worldmap

# %%
merged_df.plot(column='recorded_years',
           figsize=(15, 5),
           legend=True,cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 merged_df.plot(column='has_data',
#       2            figsize=(15, 5),
#       3            legend=True,cmap='viridis')
#
# NameError: name 'merged_df' is not defined

# %% [markdown]
# # Plot suidice per 100k rates for country, year etc
# confused about per 100k colum: how to aggregate them to get per year value? mean? does not seem to fit visualizations on kaggle
# => not possible. simply recalcualte by summing population and suicides_no in all categories and them take the mean over the years

# %%
def add_per100k(df):
    df['per100k'] = ((df.suicides_no / df.population) * 100_000)
    return df

# %%
by_country_and_year = tidy_df.groupby(['country', 'year'])[
    ['population', 'suicides_no']].sum(numeric_only=True)
by_country_and_year['per100k'] = (
    by_country_and_year['suicides_no'] / by_country_and_year['population']) * 100_000
# by_country_and_year[['country','per100k']].mean('per100k')
country_alltime_avg = by_country_and_year.groupby('country').mean('per100k')
country_alltime_avg = country_alltime_avg.per100k
print(country_alltime_avg.filter(items=['Germany']))
country_alltime_avg = country_alltime_avg.sort_values()
country_alltime_avg[-20:].plot.barh()
# country_alltime_avg.plot.barh(x='per100k', y='country')
# country_alltime_avg.per100k.plot.barh()
# Out:
# country
# Germany   14.4057216400
# Name: per100k, dtype: float64
# <AxesSubplot: ylabel='country'>

# %%
# ger_2015 = tidy_df[tidy_df.year == 2015][tidy_df.country == 'Germany'][['population','suicides_no']].sum(numeric_only=True)
# ger_2015['per100k'] = ((ger_2015.suicides_no / ger_2015.population) * 100_000)
# ger_2015

# %%
avg_1995 = tidy_df[tidy_df.year == 1995][['population','suicides_no']].sum()
add_per100k(avg_1995)
avg_1995
# Out:
# population    1591559103.0000000000
# suicides_no       243544.0000000000
# per100k               15.3022278306
# dtype: float64

# %% [markdown]
# # NOTE
# reported values on kaggle are not averages over country per 100k but rather the facotr : sum all suicides/ sum all popluation

# %%
# plot avg per 100k rate across all coutnries per year in a line plot
tidy_df = utils.load_suicide_data()

avg_per_year = tidy_df.groupby(['year'])[
    ['population', 'suicides_no']].sum(numeric_only=True)
add_per100k(avg_per_year)
# avg_per_year.mean('per100k', axis='column')
# global_mean =
fig, ax = plt.subplots(figsize=(10, 5))  # for size of figure

t = sns.lineplot(data=avg_per_year.per100k, markers=True, ax=ax, marker="o")
ticks = np.arange(1985, 2016, 2)
t.set_xticks(ticks, labels=ticks)
t.axhline(avg_per_year.per100k.mean(), linestyle='--', color='blue')

# %% [markdown]
# ## group trends separated by gender

# %%
avg_by_sex = tidy_df.groupby('sex')[
    ['population', 'suicides_no']].sum(numeric_only=True)
add_per100k(avg_by_sex)
p = avg_by_sex.per100k.plot.bar()
p.set_yticks(np.arange(0,22,1))
p.set_ylabel('Suicides per 100k')
# Out:
# Text(0, 0.5, 'Suicides per 100k')

# %%
# same for trend over time
avg_by_sex_per_year = tidy_df.groupby(['sex','year'])[
    ['population', 'suicides_no']].sum(numeric_only=True)
add_per100k(avg_by_sex_per_year)
avg_by_sex_per_year= avg_by_sex_per_year.reset_index()
male = avg_by_sex_per_year[avg_by_sex_per_year.sex == 'male']
female= avg_by_sex_per_year[avg_by_sex_per_year.sex == 'female']
fig, ax = plt.subplots(1,3, figsize=(12,5))
yticks = np.arange(5,25,2)
t1 = sns.lineplot(data=avg_by_sex_per_year, x="year", y="per100k", ax=ax[0], hue="sex",markers=True,marker="o")
t1.set_yticks(yticks)
t2 = sns.lineplot(data=male, x="year", y="per100k", ax=ax[1],markers=True,marker="o", color='blue')
t2.set_yticks(yticks)
t3 = sns.lineplot(data=female, x="year", y="per100k", ax=ax[2],markers=True,marker="o")
t3.set_yticks(yticks)
# Out:
# [<matplotlib.axis.YTick at 0x7f8830c24430>,
#  <matplotlib.axis.YTick at 0x7f8830bf3d90>,
#  <matplotlib.axis.YTick at 0x7f8830e79b10>,
#  <matplotlib.axis.YTick at 0x7f8830e7a380>,
#  <matplotlib.axis.YTick at 0x7f8830e7ae30>,
#  <matplotlib.axis.YTick at 0x7f8830e79120>,
#  <matplotlib.axis.YTick at 0x7f8830e7b760>,
#  <matplotlib.axis.YTick at 0x7f8830e9c280>,
#  <matplotlib.axis.YTick at 0x7f8830e9cd30>,
#  <matplotlib.axis.YTick at 0x7f8830e7b0d0>]

# %% [markdown]
# ## analyze country trends

# %%
by_country_and_year = tidy_df.groupby(['country', 'year'])[
    ['population', 'suicides_no']].sum(numeric_only=True)
add_per100k(by_country_and_year)
by_country_and_year = by_country_and_year.reset_index()[
    ['country', 'year', 'per100k']]
by_country_and_year
# by_country_and_year= by_country_and_year[by_country_and_year.country == 'Germany']
# sns.relplot(data=by_country_and_year,x="year",y="per100k", col="country",kind="scatter", col_wrap=8)


def trendline(x, y, order=1):
    slope = np.polyfit(x, y, order)[-2]
    return float(slope)

def apply_trendline(df):
    return trendline(df.year.values, df.per100k.values)

trends = by_country_and_year.groupby('country').apply(apply_trendline).sort_values()[::-1]
# sns.scatterplot(trends_per_country, y='country')
fig, ax = plt.subplots(figsize=(3,12))
sns.scatterplot(x=trends.values, y=trends.keys(), ax=ax)
# Out:
# <AxesSubplot: ylabel='country'>

# %%
top_n_incr_trends = by_country_and_year[by_country_and_year.country.isin(trends[:6].keys())]
sns.relplot(data=top_n_incr_trends, x='year',y='per100k', col='country', col_wrap=2, kind='line')
top_n_decr_trends = by_country_and_year[by_country_and_year.country.isin(trends[-6:].keys())]
sns.relplot(data=top_n_decr_trends, x='year',y='per100k', col='country', col_wrap=2, kind='line')
